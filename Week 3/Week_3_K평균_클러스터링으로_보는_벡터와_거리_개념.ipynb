# %% [markdown]
# <a href="https://colab.research.google.com/github/seungah-lab/Intelligence-powered-epidemiology/blob/main/Week_3_K%ED%8F%89%EA%B7%A0_%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0%EB%A7%81%EC%9C%BC%EB%A1%9C_%EB%B3%B4%EB%8A%94_%EB%B2%A1%ED%84%B0%EC%99%80_%EA%B1%B0%EB%A6%AC_%EA%B0%9C%EB%85%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### K평균 클러스터링으로 보는 차원 축소

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %% [markdown]
# ### 1. 100명의 가상 환자 데이터 생성 (특징 2개: 혈압, 콜레스테롤)
# ### 센터를 3개로 설정하여 명확한 그룹이 생기도록 합니다.

# %%
X, y_true = make_blobs(n_samples=100, centers=3, cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50)

# %% [markdown]
# ### 2. k-means 모델 설정 (k=3)
# ### 환자들을 3개의 위험군으로 나눈다고 하면

# %%
kmeans = KMeans(n_clusters=3, random_state=0)

# %% [markdown]
# ### 3. 모델 학습
# ### 인공지능이 데이터 사이의 거리를 계산하여 그룹을 찾음

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %% [markdown]
# ### 4. 결과 예측

# %%
y_kmeans = kmeans.predict(X)

# %% [markdown]
# ### 5. 시각화

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis') # 환자 데이터 점
centers = kmeans.cluster_centers_ # 각 그룹의 중심점
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5, marker='X') # 중심점 표시
plt.title("Patient Clustering (k=3)")
plt.xlabel("Blood Pressure (scaled)")
plt.ylabel("Cholesterol (scaled)")
plt.show()
